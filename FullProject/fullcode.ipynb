# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("../data/raw/hogwarts_sorting.csv")

# %%
df.dtypes
# Out:
# Blood Status           object
# Bravery                 int64
# Intelligence            int64
# Loyalty                 int64
# Ambition                int64
# Dark Arts Knowledge     int64
# Quidditch Skills        int64
# Dueling Skills          int64
# Creativity              int64
# House                  object
# dtype: object

# %%
df.drop(columns=['Blood Status','Dark Arts Knowledge','Quidditch Skills','Dueling Skills'])
# Out:
#      Bravery  Intelligence  Loyalty  Ambition  Creativity       House
# 0          9             4        7         5           7  Gryffindor
# 1          6             8        5         7           9   Ravenclaw
# 2          1             4        7         7           6  Hufflepuff
# 3          9             1        3         4           1  Gryffindor
# 4          5             9        7         3           9   Ravenclaw
# ..       ...           ...      ...       ...         ...         ...
# 995        7            10        3         7           8   Ravenclaw
# 996        7             3        2         7           7   Slytherin
# 997        5            10        5         3          10   Ravenclaw
# 998        5             6       10         4           4  Hufflepuff
# 999        7             1       10         5           3  Hufflepuff
#
# [1000 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier

# %%
X = df[['Bravery', 'Intelligence', 'Loyalty', 'Ambition', 'Creativity']]
y = df['House']

# %%
target_encoder = LabelEncoder()
y_encoded = target_encoder.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=6, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=6, random_state=42)

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred = model.predict(X_test)
print(f"Production Model Accuracy: {accuracy_score(y_test, y_pred):.2%}")
print(classification_report(y_test, y_pred, target_names=target_encoder.classes_))
# Out:
# Production Model Accuracy: 98.00%
#               precision    recall  f1-score   support
#
#   Gryffindor       1.00      0.98      0.99        45
#   Hufflepuff       0.93      1.00      0.96        50
#    Ravenclaw       1.00      0.98      0.99        52
#    Slytherin       1.00      0.96      0.98        53
#
#     accuracy                           0.98       200
#    macro avg       0.98      0.98      0.98       200
# weighted avg       0.98      0.98      0.98       200

# %%
import joblib

# %%
joblib.dump(model, 'hogwarts_rf_model.pkl')
joblib.dump(target_encoder, 'target_encoder.pkl')
# Out:
# ['target_encoder.pkl']
