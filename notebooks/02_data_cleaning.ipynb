# %%
import pandas as pd
df=pd.read_csv("../data/raw/hogwarts_sorting.csv")

df.isnull().sum()
# Out:
# Blood Status           0
# Bravery                0
# Intelligence           0
# Loyalty                0
# Ambition               0
# Dark Arts Knowledge    0
# Quidditch Skills       0
# Dueling Skills         0
# Creativity             0
# House                  0
# dtype: int64

# %%
df.dropna(inplace=True)
df['Bravery'].fillna(df['Bravery'].mean(), inplace=True)
df['Blood Status'].fillna(df['Blood Status'].mode()[0], inplace=True)

df.fillna(method='ffill', inplace=True)
df.fillna(method='bfill', inplace=True)

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
# Out:
# 0

# %%
df.drop(columns=['Dark Arts Knowledge','Quidditch Skills','Dueling Skills'], inplace=True)

# %%
df.rename(columns={'Blood Status': 'Blood_Status'}, inplace=True)
df.rename(columns={'Bravery': 'Bravery_Score'}, inplace=True)

# %%
df['House']=df['House'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Blood_Status   1000 non-null   object
#  1   Bravery_Score  1000 non-null   int64
#  2   Intelligence   1000 non-null   int64
#  3   Loyalty        1000 non-null   int64
#  4   Ambition       1000 non-null   int64
#  5   Creativity     1000 non-null   int64
#  6   House          1000 non-null   category
# dtypes: category(1), int64(5), object(1)
# memory usage: 48.2+ KB
